# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-3270/dslab/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
response=requests.get(url)
issues=response.json()
df_issues=pd.DataFrame(issues)
print(df_issues[['id','title','state','created_at']].head())
# Out:
#            id                                              title state  \
# 0  5139963341  DOC: Update DataFrame and Index docs to say th...  open
# 1  5139713103  DOC: Update DataFrame and Index docs to mentio...  open
# 2  5137705574  BUG: raise OutOfBoundsDatetime when nonexisten...  open
# 3  5136202433  DOC: Document dict acceptance for Index and Da...  open
# 4  5134518622  DISCUSSION:  Should `pandas` allow any non-str...  open
#
#              created_at
# 0  2026-08-13T09:40:04Z
# 1  2026-08-13T09:08:59Z
# 2  2026-08-13T04:10:56Z
# 3  2026-08-12T23:26:08Z
# 4  2026-08-12T19:22:59Z

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("student.db")
cursor=conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS student(id NUMBER,name TEXT)''')
cursor.execute("INSERT INTO student VALUES(1,'John')")
conn.commit()
cursor.execute("INSERT INTO student VALUES(2,'Joy')")
conn.commit()
df=pd.read_sql_query("SELECT * FROM student",conn)
print(df)
cursor.execute("UPDATE student SET name='Alice' WHERE id=1")
cursor.execute("DELETE FROM student WHERE id=1")
conn.commit()
conn.close()
# Out:
#    id  name
# 0   1  John
# 1   2   Joy
